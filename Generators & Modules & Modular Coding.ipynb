# %%
#return 1 to n numbers using functions.
def fun(n):
    lst=[]
    for i in range(1,n+1):
        lst.append(i)
    return lst
fun(5)
# Out:
# [1, 2, 3, 4, 5]

# %%
import sys                  #sys=system
def fun(n):
    lst=[]
    for i in range(1,n+1):
        lst.append(i)
    return lst
r=fun(5)
print(sys.getsizeof(r))
print(r)
# Out:
# 120
# [1, 2, 3, 4, 5]

# %%
#return 1 to n numbers using generator.
import sys                
def gen(n):
    lst=[]
    for i in range(1,n+1):
        yield i
r=gen(3)
print(r)
n=next(r)
print(sys.getsizeof(n))
print(n)
print(next(r))
print(next(r))
print(next(r))
print(next(r))     #StopIteration,Because there is no element left to get value in generator object.
# Out:
# <generator object gen at 0x0000028B0BA209A0>
# 28
# 1
# 2
# 3
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[13], line 14
#      10 print(sys.getsizeof(n))
#      11 print(n)
#      12 print(next(r))
#      13 print(next(r))
# ---> 14 print(next(r))
#      15 print(next(r))     #StopIteration,Because there is no element left to get value in generator object.
#
# StopIteration:

# %%
import sys                
def gen(n):
    lst=[]
    for i in range(1,n+1):
        yield i
r=gen(3)
print(r)
#to stop the stopiteration error by loop.
for val in r:
    print(val)
# Out:
# <generator object gen at 0x0000028B0BA209A0>
# 1
# 2
# 3

# %%
import sys                
def gen(n):
    lst=[]
    for i in range(1,n+1):
        yield i**3
r=gen(1000)
print(r)
for val in r:
    print(val,end=" ")
# Out:
# <generator object gen at 0x0000028B0BA208B0>
# ...

# %%
import time
import sys      
s=time.time()
def gen(n):
    for i in range(1,n+1):
        yield i**3
r=gen(100)
print(r)
for val in r:
    print(val,end=" ")
print()
e=time.time()
print(e-s)
# Out:
# <generator object gen at 0x0000028B0BA38820>
# 1 8 27 64 125 216 343 512 729 1000 1331 1728 2197 2744 3375 4096 4913 5832 6859 8000 9261 10648 12167 13824 15625 17576 19683 21952 24389 27000 29791 32768 35937 39304 42875 46656 50653 54872 59319 64000 68921 74088 79507 85184 91125 97336 103823 110592 117649 125000 132651 140608 148877 157464 166375 175616 185193 195112 205379 216000 226981 238328 250047 262144 274625 287496 300763 314432 328509 343000 357911 373248 389017 405224 421875 438976 456533 474552 493039 512000 531441 551368 571787 592704 614125 636056 658503 681472 704969 729000 753571 778688 804357 830584 857375 884736 912673 941192 970299 1000000
# 0.0036466121673583984

# %%
def gen(x):
    x=x+1
    yield x
    x=x+2
    x=x+3
    yield x
    x+=5
    x+=6
    yield x
res=gen(10)
print(res)
print(next(res))
print(next(res))
# Out:
# <generator object gen at 0x0000028B0BBD6680>
# 11
# 16

# %%
#Generator Expression
gen=(x for x in range(1,11))
print(type(gen))
print(gen)
# Out:
# <class 'generator'>
# <generator object <genexpr> at 0x0000028B0BA2C790>
