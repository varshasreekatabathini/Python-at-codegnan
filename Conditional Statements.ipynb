# %%
#Check whether a number divisible by 3
n=int(input())
if n%3==0:
    print(f"{n} is divisible by 3")
else:
    print(f"{n} is not divisible by 3")
# Out:
#  27
# 27 is divisible by 3

# %%
#Check a number is divisible by 3 and 5
n=int(input())
if n%3==0 and n%5==0:
    print(f"{n} is divisible by 3 and 5")
else:
    print(f"{n} is not divisible by 3 and 5")
# Out:
#  6
# 6 is not divisible by 3 and 5

# %%
#Check a number is divisible by 3 or 5
n=int(input())
if n%3==0 or n%5==0:
    print(f"{n} is divisible by either 3 or 5")
else:
    print(f"{n} is not divisible by either 3 or 5")
# Out:
#  50
# 50 is divisible by either 3 or 5

# %%
#check whether a number is even or odd
x=int(input())
if x%2==0:
    print("Even")
else:
    print("Odd")
# Out:
#  5
# Odd

# %%
x=int(input())
if x & 1 == 0:             # we also use if x%2:
    print(f"{x} is Even")
else:
    print(f"{x} is Odd")
# Out:
#  35
# 35 is Odd

# %%
#Generate total bill if total bill more than 500 then give 10% discount otherwise 0% discount
bill=int(input())
if bill>500:
    print("10% discount")
else:
    print("0% discount")
# Out:
#  550
# 10% discount

# %%
#Generate total bill if total bill more than 500 then give 10% discount otherwise 0% discount
total_bill=int(input())
if total_bill>500:
    discount=total_bill*0.1
    print(f"Total bill after 10% discount: {total_bill-discount}")
else:
    print(f"Total bill after 0% discount: {total_bill}")
# Out:
#  550
# Total bill after 10% discount: 495.0

# %%
#Check whether the product stock is available or not (read product name and stock)
stock=input()
product=input()
if product in stock:
    print("The product is available")
else:
    print("The product is not available")
# Out:
#  chips,cooldrinks,fruits,chocolates
#  sweets
# The product is not available

# %%
#Check whether the product stock is available or not (read product name and stock)
product=input()
stock=int(input())
if stock>0:
    print(f"currently {product} : {stock} items available")
else:
    print(f"currently {product} out of stock")
# Out:
#  pen
#  5
# currently pen : 5 items available

# %%
#In a shop contains some items along with prices like {'pen':5,'book':20,'pencil':3}
products={'pen':5, 'book':20, 'pencil':3}
item=input().lower()
quantity=int(input())
if item in products:
    total_amount=products.get(item) * quantity
    print(f"Total amount of {quantity} {item} is: {total_amount}")
else:
    print(f"{item} not available")
# Out:
#  PEN
#  5
# Total amount of 5 pen is: 25

# %%
#Check weather the number is +ve ,-ve or zero
num=int(input())
if num > 0:
    print(f'{num} is +ve')
elif num<0:
    print(f'{num} is -ve')
else:
    print(f'{num} is zero')
# Out:
#  -5
# -5 is -ve

# %%
#divisible by 3 - Fizz
#divisible by 5 - Buzz
#Both - FizzBuzz
n=int(input())
if n%3==0 and n%5==0:
    print("FizzBuzz")
elif n%3==0:
    print("Fizz")
elif n%5==0:
    print("Buzz")
else:
    print("Not divisible by 3 and 5")
# Out:
#  15
# FizzBuzz

# %%
#Check whether a number +ve even,-ve even,+ve odd,-ve odd
n=int(input())
if n>=0 and n%2==0:
    print("Positive Even")
elif n<0 and n%2==0:
    print("Negative Even")
elif n>0 and n%2!=0:
    print("Positive Odd")
elif n<0 and n%2!=0:
    print("Negative Odd")
# Out:
#  -5
# Negative Odd

# %%
n=int(input())
# +ve even or not
if n>=0 and n%2==0:
    print(f"{n} Positive Even")
elif n>0:
    print(f"{n} Positive Odd")
#-ve even or not
elif n%2==0:
    print(f"{n} Negative Even")
else:
    print(f"{n} Negative odd")
# Out:
#  5
# 5 Positive Odd

# %%
# Find the biggest number among three numbers
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c:
    print(f"{a} is Bigger")
elif b>c:
    print(f"{b} is Bigger")
else:
    print(f"{c} is Bigger")
# Out:
#  10
#  20
#  30
# 30 is Bigger

# %%
#Find the biggest number among three numbers
a=int(input())
b=int(input())
c=int(input())
if a>b and a>c:
    print(f"{a} is Bigger")
elif b>c and b>a:
    print(f"{b} is Bigger")
else:
    print(f"{c} is Bigger")
# Out:
#  12
#  2
#  3
# 12 is Bigger

# %%
# Find the Smallest number among three numbers
a=int(input())
b=int(input())
c=int(input())
if a<b and a<c:
    print(f"{a} is Smallest")
elif b<c:
    print(f"{b} is Smallest")
else:
    print(f"{c} is Smallest")
# Out:
#  2
#  3
#  5
# 2 is Smallest

# %%
#Nested if 
#even or odd
n=int(input())
if n>=0:
    if n%2==0:
        print("+Even")
    else:
        print("+Odd")
else:
    if n%2==0:
        print("-ve Even")
    else:
        print("-ve Odd")
# Out:
#  -5
# -ve Odd

# %%
#Bigger 
n1,n2,n3=map(int,input().split())
if n1>n2:
    if n1>n3:
        print(n1,"is greater")
    else:
        print(n3,"is greater")
else:
    if n2>n3:
        print(n2,"is greater")
    else:
        print(n3,"is greater")
# Out:
#  10 9 8
# 10 is greater

# %%
n=n1,n2,n3=map(int,input().split())
if n1%2==0:
    print(f'{n1} is even')
else:
    print(f'{n1} is odd')
if n2%2==0:
    print(f'{n2} is even')
else:
    print(f'{n2} is odd')
if n3%2==0:
    print(f'{n3} is even')
else:
    print(f'{n3} is odd')
# Out:
#  1 2 5
# 1 is odd
# 2 is even
# 5 is odd
